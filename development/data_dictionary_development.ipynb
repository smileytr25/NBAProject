# %%
import pandas as pd
from pathlib import Path 
from sqlalchemy import create_engine

# %%
data_dictionary = [
    ["all-defensive_history", "player", "Player receiving the accolade", "TEXT"],
    ["all-defensive_history", "accolade", "Accolade the player received", "TEXT"],
    ["all-defensive_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["all-nba_history", "player", "Player receiving the accolade", "TEXT"],
    ["all-nba_history", "accolade", "Accolade the player received", "TEXT"],
    ["all-nba_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["all-rookie_history", "player", "Player receiving the accolade", "TEXT"],
    ["all-rookie_history", "accolade", "Accolade the player received", "TEXT"],
    ["all-rookie_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["all-star_history", "player", "Player receiving the accolade", "TEXT"],
    ["all-star_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["all-tournament_history", "player", "Player receiving the accolade", "TEXT"],
    ["all-tournament_history", "accolade", "Accolade the player received", "TEXT"],
    ["all-tournament_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["coaches_history", "coach", "Name of coach", "TEXT"],
    ["coaches_history", "team", "Team the coach was associated with", "TEXT"],
    ["coaches_history", "with_franchise_seasons", "Number of seasons spent with the current team", "BIGINT"],
    ["coaches_history", "overall_seasons", "Number of seasons spent across all teams", "BIGINT"],
    ["coaches_history", "current_regular_season_games", "Number of games coached in the regular season of the current year", "BIGINT"],
    ["coaches_history", "current_regular_season_wins", "Number of wins as coach in the regular season of the current year", "BIGINT"],
    ["coaches_history", "current_regular_season_losses", "Number of losses as coach in the regular season of the current year", "BIGINT"],
    ["coaches_history", "with_franchise_regular_season_games", "Number of total regular season games coached while with the franchise", "BIGINT"],
    ["coaches_history", "with_franchise_regular_season_wins", "Number of total regular season wins as coach while with the franchise", "BIGINT"],
    ["coaches_history", "with_franchise_regular_season_losses", "Number of total regular season losses as coach while with the franchise", "BIGINT"],
    ["coaches_history", "career_regular_season_games", "Number of games coached in the regular season across the course of career", "BIGINT"],
    ["coaches_history", "career_regular_season_wins", "Number of regular season games won as the coach across the course of career", "BIGINT"],
    ["coaches_history", "career_regular_season_losses", "Number of regular season games lost as the coach across the course of career", "BIGINT"],
    ["coaches_histoyr", "career_win_percentage", "Percentage of career regular season games that the coach won", "FLOAT"],
    ["coaches_history", "current_playoff_games", "Number of games coached in the playoffs of the current year", "BIGINT"],
    ["coaches_history", "current_playoff_wins", "Number of wins as coach in the playoffs of the current year", "BIGINT"],
    ["coaches_history", "current_playoff_losses", "Number of losses as coach in the playoffs of the current year", "BIGINT"],
    ["coaches_history", "with_franchise_playoff_games", "Number of total playoff games coached while with the franchise", "BIGINT"],
    ["coaches_history", "with_franchise_playoff_wins", "Number of total playoff wins as coach while with the franchise", "BIGINT"],
    ["coaches_history", "with_franchise_playoff_losses", "Number of total playoff losses as coach while with the franchise", "BIGINT"],
    ["coaches_history", "career_playoff_games", "Number of games coached in the playoffs across the course of career", "BIGINT"],
    ["coaches_history", "career_playoff_wins", "Number of playoff games won as the coach across the course of career", "BIGINT"],
    ["coaches_history", "career_playoff_losses", "Number of playoff games lost as the coach across the course of career", "BIGINT"],
    ["coaches_history", "year", "Ending year of the record's associated season", "BIGINT"],
    ["draft_history", "Pk", "Pick number in the associated draft", "TEXT"],
    ["draft_history", "Tm", "Team drafting at the associated pick number", "TEXT"],
    ["draft_history", "Player", "Player drafted at the associated pick number", "TEXT"],
    ["draft_history", "College", "College or university that the drafted player attended, none if international player", "TEXT"],
    ["draft_history", "Year", "NBA drafty year", "BIGINT"],
    ["franchise_histories", "Franchise", "Name of the franchise", "TEXT"],
    ["franchise_histories", "Lg", "Name of the league the franchise was a member of", "TEXT"],
    ["franchise_histories", "From", "The year the franchise was established", "BIGINT"],
    ["franchise_histories", "To", "The last year of membership before the franchise became defunct", "BIGINT"],
    ["franchise_histories", "Yrs", "Number of years the franchise was active", "BIGINT"],
    ["franchise_histories", "G", "Number of total games played by the associated franchise", "BIGINT"],
    ["franchise_histories", "W", "Number of total games won by the associated franchise", "BIGINT"],
    ["franchise_histories", "L", "Number of total games lost by the associated franchise", "BIGINT"],
    ["franchise_histories", "W/L%", "Percentage of all games won by the associated franchise", "FLOAT"],
    ["franchise_histories", "Plyfs", "Number of playoff appearances by the associated franchise", "BIGINT"],
    ["franchise_histories", "Div", "Number of division titles won by the associated franchise", "BIGINT"],
    ["franchise_histories", "Conf", "Number of conference championships won by the associated franchise", "BIGINT"],
    ["franchise_histories", "Champ", "Number of league championships won by the associated franchise", "BIGINT"],
    ["game_schedule_history", "Date", "Scheduled date of the associated game", "DATETIME"],
    ["game_schedule_history", "Visitor", "Name of the visiting franchise for the associated game", "TEXT"],
    ["game_schedule_history", "Visitor_PTS", "Number of points scored by the visiting franchise of the associated game", "TEXT"],
    ["game_schedule_history", "Home", "Name of the home franchise for the associated game", "TEXT"],
    ["game_schedule_history", "Home_PTS", "Number of points scored by the home franchise of the associated game", "TEXT"],
    ["game_schedule_history", "Overtime", "Categorical text label specifying the last overtime period played in the associated game, None means OT was not needed", "TEXT"],
    ["game_schedule_history", "Attendance", "Number of people that attended the associated game", "TEXT"],
    ["game_schedule_history", "Arena", "The name of the arena the associated game was played in", "TEXT"],
    ["game_schedule_history", "Game_Notes", "Additional notes about the associated games context, location, or stakes", "TEXT"],
    ["game_schedule_history", "Start_Time", "The start time of the associated game (EST)", "DATETIME"],
    ["head_to_head_history", "year", "Ending year of the head to head record's associated season", "BIGINT"],
    ["head_to_head_history", "team", "The name of the head to head record's perspective franchise", "TEXT"],
    ["head_to_head_history", "against", "The name of the head to head record's perspective opposing franchise", "TEXT"],
    ["head_to_head_history", "wins", "The number of games won by the perspective franchise against the opposition", "BIGINT"],
    ["head_to_head_history", "losses", "The number of games lost by the perspective franchise against the opposition", "BIGINT"],
    ["league_awards_history", "player", "Player receiving the accolade", "TEXT"],
    ["league_awards_history", "accolade", "Accolade the player received", "TEXT"],
    ["league_awards_history", "year", "Year of season the accolade was received", "BIGINT"],
    ["season_teams", "Franchise", "Name of the franchise", "TEXT"],
    ["season_teams", "Year", "The ending year of the associated season", "BIGINT"],
    ["standings_history_1950", "rank", "The league-wide standings rank of the associated franchise", "BIGINT"],
    ["standings_history_1950", "team", "Name of the franchise", "TEXT"],
    ["standings_history_1950", "wins", "Number of games won by the associated franchise", "BIGINT"],
    ["standings_history_1950", "losses", "Number of games lost by the associated franchise", "BIGINT"],
    ["standings_history_1950", "home_wins", "Number of games won by the associated franchise as the home team", "BIGINT"],
    ["standings_history_1950", "home_losses", "Number of games lost by the associated franchise as the home team", "BIGINT"],
    ["standings_history_1950", "away_wins", "Number of games won by the associated franchise as the away team", "BIGINT"],
    ["standings_history_1950", "away_losses", "Number of games lost by the associated franchise as the away team", "BIGINT"],
    ["standings_history_1950", "neutral_wins", "Number of games won by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_1950", "neutral_losses", "Number of games lost by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_1950", "central_wins", "Number of games won by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_1950", "central_losses", "Number of games lost by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_1950", "eastern_wins", "Number of games won by the associated franchise against opponents within the eastern division", "BIGINT"],
    ["standings_history_1950", "eastern_losses", "Number of games lost by the associated franchise against opponents within the eastern division", "BIGINT"],
    ["standings_history_1950", "western_wins", "Number of games won by the associated franchise against opponents within the western division", "BIGINT"],
    ["standings_history_1950", "western_losses", "Number of games lost by the associated franchise against opponents within the western division", "BIGINT"],
    ["standings_history_1950", "within_3pt_wins", "Number of games won by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_1950", "within_3pt_losses", "Number of games lost by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_1950", "outside_10pt_wins", "Number of games won by the associated franchise in games decided by 10 points or more", "BIGINT"],
    ["standings_history_1950", "outside_10pt_losses", "Number of games lost by the associated franchise in games decided by 10 points or less", "BIGINT"],
    ["standings_history_1950", "october_wins", "Number of games won by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_1950", "october_losses", "Number of games lost by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_1950", "november_wins", "Number of games won by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_1950", "november_losses", "Number of games lost by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_1950", "december_wins", "Number of games won by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_1950", "december_losses", "Number of games lost by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_1950", "january_wins", "Number of games won by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_1950", "january_losses", "Number of games lost by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_1950", "february_wins", "Number of games won by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_1950", "february_losses", "Number of games lost by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_1950", "march_wins", "Number of games won by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_1950", "march_losses", "Number of games lost by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_1950", "division", "Division membership of the associated franchise", "TEXT"],
    ["standings_history_1950", "win_percentage", "Percentage of games won by the associated franchise", "FLOAT"],
    ["standings_history_1950", "home_win_percentage", "Percentage of home games won by the associated franchise", "FLOAT"],
    ["standings_history_1950", "away_win_percentage", "Percentage of away games won by the associated franchise", "FLOAT"],
    ["standings_history_1950", "year", "The ending year of the associated NBA season", "BIGINT"],
    ["standings_history_after_1950_to_1970", "rank", "The league-wide standings rank of the associated franchise", "BIGINT"],
    ["standings_history_after_1950_to_1970", "team", "Name of the franchise", "TEXT"],
    ["standings_history_after_1950_to_1970", "wins", "Number of games won by the associated franchise", "BIGINT"],
    ["standings_history_after_1950_to_1970", "losses", "Number of games lost by the associated franchise", "BIGINT"],
    ["standings_history_after_1950_to_1970", "home_wins", "Number of games won by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_1950_to_1970", "home_losses", "Number of games lost by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_1950_to_1970", "away_wins", "Number of games won by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_1950_to_1970", "away_losses", "Number of games lost by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_1950_to_1970", "neutral_wins", "Number of games won by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_1950_to_1970", "neutral_losses", "Number of games lost by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_1950_to_1970", "eastern_wins", "Number of games won by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_1950_to_1970", "eastern_losses", "Number of games lost by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_1950_to_1970", "western_wins", "Number of games won by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_1950_to_1970", "western_losses", "Number of games lost by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_1950_to_1970", "pre_allstar_wins", "Number of games won by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_1950_to_1970", "pre_allstar_losses", "Number of games lost by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_1950_to_1970", "post_allstar_wins", "Number of games won by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_after_1950_to_1970", "post_allstar_losses", "Number of games lost by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_ater_1950_to_1970", "within_3pt_wins", "Number of games won by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_1950_to_1970", "within_3pt_losses", "Number of games lost by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_1950_to_1970", "outside_10pt_wins", "Number of games won by the associated franchise in games decided by 10 points or more", "BIGINT"],
    ["standings_history_after_1950_to_1970", "outside_10pt_losses", "Number of games lost by the associated franchise in games decided by 10 points or less", "BIGINT"],
    ["standings_history_after_1950_to_1970", "october_wins", "Number of games won by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_1950_to_1970", "october_losses", "Number of games lost by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_1950_to_1970", "november_wins", "Number of games won by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_1950_to_1970", "november_losses", "Number of games lost by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_1950_to_1970", "december_wins", "Number of games won by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_1950_to_1970", "december_losses", "Number of games lost by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_1950_to_1970", "january_wins", "Number of games won by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_1950_to_1970", "january_losses", "Number of games lost by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_1950_to_1970", "february_wins", "Number of games won by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_1950_to_1970", "february_losses", "Number of games lost by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_1950_to_1970", "march_wins", "Number of games won by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_1950_to_1970", "march_losses", "Number of games lost by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_1950_to_1970", "division", "Division membership of the associated franchise", "TEXT"],
    ["standings_history_after_1950_to_1970", "win_percentage", "Percentage of games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1950_to_1970", "home_win_percentage", "Percentage of home games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1950_to_1970", "away_win_percentage", "Percentage of away games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1950_to_1970", "year", "The ending year of the associated NBA season"],
    ["standings_history_after_1970_to_2004", "rank", "The league-wide standings rank of the associated franchise", "BIGINT"],
    ["standings_history_after_1970_to_2004", "conference_rank", "The conference standings rank of the associated franchise", "FLOAT"],
    ["standings_history_after_1970_to_2004", "team", "Name of the franchise", "TEXT"],
    ["standings_history_after_1970_to_2004", "wins", "Number of games won by the associated franchise", "BIGINT"],
    ["standings_history_after_1970_to_2004", "losses", "Number of games lost by the associated franchise", "BIGINT"],
    ["standings_history_after_1970_to_2004", "home_wins", "Number of games won by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_1970_to_2004", "home_losses", "Number of games lost by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_1970_to_2004", "away_wins", "Number of games won by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_1970_to_2004", "away_losses", "Number of games lost by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_1970_to_2004", "neutral_wins", "Number of games won by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_1970_to_2004", "neutral_losses", "Number of games lost by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_1970_to_2004", "eastern_wins", "Number of games won by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_1970_to_2004", "eastern_losses", "Number of games lost by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_1970_to_2004", "western_wins", "Number of games won by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_1970_to_2004", "western_losses", "Number of games lost by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_1970_to_2004", "atlantic_wins", "Number of games won by the associated franchise against opponents within the atlantic division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "atlantic_losses", "Number of games lost by the associated franchise against opponents within the atlantic division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "central_wins", "Number of games won by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "central_losses", "Number of games lost by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "midwest_wins", "Number of games won by the associated franchise against opponents within the midwest division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "midwest_losses", "Number of games lost by the associated franchise against opponents within the midwest division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "pacific_wins", "Number of games won by the associated franchise against opponents within the pacific division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "pacific_losses", "Number of games lost by the associated franchise against opponents within the pacific division", "BIGINT"],
    ["standings_history_after_1970_to_2004", "pre_allstar_wins", "Number of games won by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_1970_to_2004", "pre_allstar_losses", "Number of games lost by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_1970_to_2004", "post_allstar_wins", "Number of games won by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_after_1970_to_2004", "post_allstar_losses", "Number of games lost by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_after_1970_to_2004", "within_3pt_wins", "Number of games won by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_1970_to_2004", "within_3pt_losses", "Number of games lost by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_1970_to_2004", "outside_10pt_wins", "Number of games won by the associated franchise in games decided by 10 points or more", "BIGINT"],
    ["standings_history_after_1970_to_2004", "outside_10pt_losses", "Number of games lost by the associated franchise in games decided by 10 points or less", "BIGINT"],
    ["standings_history_after_1970_to_2004", "october_wins", "Number of games won by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_1970_to_2004", "october_losses", "Number of games lost by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_1970_to_2004", "november_wins", "Number of games won by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_1970_to_2004", "november_losses", "Number of games lost by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_1970_to_2004", "december_wins", "Number of games won by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_1970_to_2004", "december_losses", "Number of games lost by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_1970_to_2004", "january_wins", "Number of games won by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_1970_to_2004", "january_losses", "Number of games lost by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_1970_to_2004", "february_wins", "Number of games won by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_1970_to_2004", "february_losses", "Number of games lost by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_1970_to_2004", "march_wins", "Number of games won by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_1970_to_2004", "march_losses", "Number of games lost by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_1970_to_2004", "april_wins", "Number of games won by the associated franchise in games played in April", "BIGINT"],
    ["standings_history_after_1970_to_2004", "april_losses", "Number of games lost by the associated franchise in games played in April", "BIGINT"],
    ["standings_history_after_1970_to_2004", "may_wins", "Number of games won by the associated franchise in games played in May", "BIGINT"],
    ["standings_history_after_1970_to_2004", "may_losses", "Number of games lost by the associated franchise in games played in May", "BIGINT"],
    ["standings_history_after_1970_to_2004", "conference", "Conference membership of the associated franchise", "TEXT"],
    ["standings_history_after_1970_to_2004", "division", "Division membership of the associated franchise", "TEXT"],
    ["standings_history_after_1970_to_2004", "win_percentage", "Percentage of games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1970_to_2004", "home_win_percentage", "Percentage of home games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1970_to_2004", "away_win_percentage", "Percentage of away games won by the associated franchise", "FLOAT"],
    ["standings_history_after_1970_to_2004", "year", "The ending year of the associated NBA season"],
    ["standings_history_after_2004", "rank", "The league-wide standings rank of the associated franchise", "BIGINT"],
    ["standings_history_after_2004", "conference_rank", "The conference standings rank of the associated franchise", "FLOAT"],
    ["standings_history_after_2004", "team", "Name of the franchise", "TEXT"],
    ["standings_history_after_2004", "wins", "Number of games won by the associated franchise", "BIGINT"],
    ["standings_history_after_2004", "losses", "Number of games lost by the associated franchise", "BIGINT"],
    ["standings_history_after_2004", "home_wins", "Number of games won by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_2004", "home_losses", "Number of games lost by the associated franchise as the home team", "BIGINT"],
    ["standings_history_after_2004", "away_wins", "Number of games won by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_2004", "away_losses", "Number of games lost by the associated franchise as the away team", "BIGINT"],
    ["standings_history_after_2004", "neutral_wins", "Number of games won by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_2004", "neutral_losses", "Number of games lost by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_after_2004", "eastern_wins", "Number of games won by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_2004", "eastern_losses", "Number of games lost by the associated franchise against opponents within the eastern conference", "BIGINT"],
    ["standings_history_after_2004", "western_wins", "Number of games won by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_2004", "western_losses", "Number of games lost by the associated franchise against opponents within the western conference", "BIGINT"],
    ["standings_history_after_2004", "atlantic_wins", "Number of games won by the associated franchise against opponents within the atlantic division", "BIGINT"],
    ["standings_history_after_2004", "atlantic_losses", "Number of games lost by the associated franchise against opponents within the atlantic division", "BIGINT"],
    ["standings_history_after_2004", "central_wins", "Number of games won by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_after_2004", "central_losses", "Number of games lost by the associated franchise against opponents within the central division", "BIGINT"],
    ["standings_history_after_2004", "southeast_wins", "Number of games won by the associated franchise against opponents within the southeast division", "BIGINT"],
    ["standings_history_after_2004", "southeast_losses", "Number of games lost by the associated franchise against opponents within the southeast division", "BIGINT"],
    ["standings_history_after_2004", "northwest_wins", "Number of games won by the associated franchise against opponents within the northwest division", "BIGINT"],
    ["standings_history_after_2004", "northwest_losses", "Number of games lost by the associated franchise against opponents within the northwest division", "BIGINT"],
    ["standings_history_after_2004", "pacific_wins", "Number of games won by the associated franchise against opponents within the pacific division", "BIGINT"],
    ["standings_history_after_2004", "pacific_losses", "Number of games lost by the associated franchise against opponents within the pacific division", "BIGINT"],
    ["standings_history_after_2004", "southwest_wins", "Number of games won by the associated franchise against opponents within the southwest division", "BIGINT"],
    ["standings_history_after_2004", "southwest_losses", "Number of games lost by the associated franchise against opponents within the southwest division", "BIGINT"],
    ["standings_history_after_2004", "pre_allstar_wins", "Number of games won by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_2004", "pre_allstar_losses", "Number of games lost by the associated franchise prior to the all-star break", "BIGINT"],
    ["standings_history_after_2004", "post_allstar_wins", "Number of games won by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_after_2004", "post_allstar_losses", "Number of games lost by the associated franchise after the all-star break", "BIGINT"],
    ["standings_history_after_2004", "within_3pt_wins", "Number of games won by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_2004", "within_3pt_losses", "Number of games lost by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_after_2004", "outside_10pt_wins", "Number of games won by the associated franchise in games decided by 10 points or more", "BIGINT"],
    ["standings_history_after_2004", "outside_10pt_losses", "Number of games lost by the associated franchise in games decided by 10 points or less", "BIGINT"],
    ["standings_history_after_2004", "october_wins", "Number of games won by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_2004", "october_losses", "Number of games lost by the associated franchise in games played in October", "BIGINT"],
    ["standings_history_after_2004", "november_wins", "Number of games won by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_2004", "november_losses", "Number of games lost by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_after_2004", "december_wins", "Number of games won by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_2004", "december_losses", "Number of games lost by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_after_2004", "january_wins", "Number of games won by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_2004", "january_losses", "Number of games lost by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_after_2004", "february_wins", "Number of games won by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_2004", "february_losses", "Number of games lost by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_after_2004", "march_wins", "Number of games won by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_2004", "march_losses", "Number of games lost by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_after_2004", "april_wins", "Number of games won by the associated franchise in games played in April", "BIGINT"],
    ["standings_history_after_2004", "april_losses", "Number of games lost by the associated franchise in games played in April", "BIGINT"],
    ["standings_history_after_2004", "may_wins", "Number of games won by the associated franchise in games played in May", "BIGINT"],
    ["standings_history_after_2004", "may_losses", "Number of games lost by the associated franchise in games played in May", "BIGINT"],
    ["standings_history_after_2004", "june_wins", "Number of games won by the associated franchise in games played in June", "BIGINT"],
    ["standings_history_after_2004", "june_losses", "Number of games lost by the associated franchise in games played in June", "BIGINT"],
    ["standings_history_after_2004", "july_wins", "Number of games won by the associated franchise in games played in July", "BIGINT"],
    ["standings_history_after_2004", "july_losses", "Number of games lost by the associated franchise in games played in July", "BIGINT"],
    ["standings_history_after_2004", "august_wins", "Number of games won by the associated franchise in games played in August", "BIGINT"],
    ["standings_history_after_2004", "august_losses", "Number of games lost by the associated franchise in games played in August", "BIGINT"],
    ["standings_history_after_2004", "conference", "Conference membership of the associated franchise", "TEXT"],
    ["standings_history_after_2004", "division", "Division membership of the associated franchise", "TEXT"],
    ["standings_history_after_2004", "win_percentage", "Percentage of games won by the associated franchise", "FLOAT"],
    ["standings_history_after_2004", "home_win_percentage", "Percentage of home games won by the associated franchise", "FLOAT"],
    ["standings_history_after_2004", "away_win_percentage", "Percentage of away games won by the associated franchise", "FLOAT"],
    ["standings_history_after_2004", "year", "The ending year of the associated NBA season"],
    ["standings_history_before_1950", "rank", "The league-wide standings rank of the associated franchise", "BIGINT"],
    ["standings_history_before_1950", "team", "Name of the franchise", "TEXT"],
    ["standings_history_before_1950", "wins", "Number of games won by the associated franchise", "BIGINT"],
    ["standings_history_before_1950", "losses", "Number of games lost by the associated franchise", "BIGINT"],
    ["standings_history_before_1950", "home_wins", "Number of games won by the associated franchise as the home team", "BIGINT"],
    ["standings_history_before_1950", "home_losses", "Number of games lost by the associated franchise as the home team", "BIGINT"],
    ["standings_history_before_1950", "away_wins", "Number of games won by the associated franchise as the away team", "BIGINT"],
    ["standings_history_before_1950", "away_losses", "Number of games lost by the associated franchise as the away team", "BIGINT"],
    ["standings_history_before_1950", "neutral_wins", "Number of games won by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_before_1950", "neutral_losses", "Number of games lost by the associated franchise within a neutral site", "BIGINT"],
    ["standings_history_before_1950", "eastern_wins", "Number of games won by the associated franchise against opponents within the eastern division", "BIGINT"],
    ["standings_history_before_1950", "eastern_losses", "Number of games lost by the associated franchise against opponents within the eastern division", "BIGINT"],
    ["standings_history_before_1950", "western_wins", "Number of games won by the associated franchise against opponents within the western division", "BIGINT"],
    ["standings_history_before_1950", "western_losses", "Number of games lost by the associated franchise against opponents within the western division", "BIGINT"],
    ["standings_history_before_1950", "within_3pt_wins", "Number of games won by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_before_1950", "within_3pt_losses", "Number of games lost by the associated franchise in games decided by 3 points or less", "BIGINT"],
    ["standings_history_before_1950", "outside_10pt_wins", "Number of games won by the associated franchise in games decided by 10 points or more", "BIGINT"],
    ["standings_history_before_1950", "outside_10pt_losses", "Number of games lost by the associated franchise in games decided by 10 points or less", "BIGINT"],
    ["standings_history_before_1950", "november_wins", "Number of games won by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_before_1950", "november_losses", "Number of games lost by the associated franchise in games played in November", "BIGINT"],
    ["standings_history_before_1950", "december_wins", "Number of games won by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_before_1950", "december_losses", "Number of games lost by the associated franchise in games played in December", "BIGINT"],
    ["standings_history_before_1950", "january_wins", "Number of games won by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_before_1950", "january_losses", "Number of games lost by the associated franchise in games played in January", "BIGINT"],
    ["standings_history_before_1950", "february_wins", "Number of games won by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_before_1950", "february_losses", "Number of games lost by the associated franchise in games played in February", "BIGINT"],
    ["standings_history_before_1950", "march_wins", "Number of games won by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_before_1950", "march_losses", "Number of games lost by the associated franchise in games played in March", "BIGINT"],
    ["standings_history_before_1950", "division", "Division membership of the associated franchise", "TEXT"],
    ["standings_history_before_1950", "win_percentage", "Percentage of games won by the associated franchise", "FLOAT"],
    ["standings_history_before_1950", "home_win_percentage", "Percentage of home games won by the associated franchise", "FLOAT"],
    ["standings_history_before_1950", "away_win_percentage", "Percentage of away games won by the associated franchise", "FLOAT"],
    ["standings_history_before_1950", "year", "The ending year of the associated NBA season", "BIGINT"],
    ["team_abbreviation_to_teamname", "abbreviation", "Franchise three letter abbreviation", "TEXT"],
    ["team_abbreviation_to_teamname", "teamname", "Full franchise team name", "TEXT"]
]

# %%
data_dictionary = pd.DataFrame(data_dictionary, columns=["table_name", "column_name", "column_description", "data_type"])

db_path = Path("~/Personal Project/data/nba.db").expanduser()
engine = create_engine(f"sqlite:///{db_path}")

data_dictionary.to_sql(
    "data_dictionary",
    engine,
    if_exists="replace",
    index=False
)
# Out:
# 303
